# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('salary_data_cleaned.csv')

# %%
df.head(100)
# Out:
#                     Job Title               Salary Estimate  \
# 0              Data Scientist    $53K-$91K (Glassdoor est.)
# 1   Healthcare Data Scientist   $63K-$112K (Glassdoor est.)
# 2              Data Scientist    $80K-$90K (Glassdoor est.)
# 3              Data Scientist    $56K-$97K (Glassdoor est.)
# 4              Data Scientist   $86K-$143K (Glassdoor est.)
# ..                        ...                           ...
# 95                  Scientist   $55K-$116K (Glassdoor est.)
# 96             Data Scientist   $72K-$123K (Glassdoor est.)
# 97             Data Scientist   $74K-$124K (Glassdoor est.)
# 98               Data Analyst    $40K-$73K (Glassdoor est.)
# 99        Lead Data Scientist  $102K-$164K (Glassdoor est.)
#
#                                       Job Description  Rating  \
# 0   Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1   What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'Employer_Provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'same state', 'age', 'python_yn',
#        'excel_yn', 'r_studio_yn', 'power_bi_yn', 'tabula_yn', 'matplotlib_yn',
#        'math', 'machine learning', 'communication skills'],
#       dtype='object')

# %%
#  Job title and seniority
def title_smiplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'

def seniority(title):
    if 'sr' in title.lower()  or 'senior' in title.lower()  or 'lead' in title.lower() or 'principal' in title.lower():
        return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower():
        return 'jr'
    else:
        return 'na'

# %%
df['job_simp'] = df['Job Title'].apply(title_smiplifier)

# %%
df.job_simp.value_counts()
# Out:
# data scientist    279
# na                184
# data engineer     119
# analyst           102
# manager            22
# mle                22
# director           14
# Name: job_simp, dtype: int64

# %%
df['seniority']  = df['Job Title'].apply(seniority)

# %%
df.seniority.value_counts()
# Out:
# na        520
# senior    220
# jr          2
# Name: seniority, dtype: int64

# %%
#job description length
df['desc_len'] = df['Job Description'].apply(lambda x: len(x))
df['desc_len']
# Out:
# 0      2536
# 1      4783
# 2      3461
# 3      3883
# 4      2728
#        ...
# 737    6162
# 738    6130
# 739    3078
# 740    1642
# 741    3673
# Name: desc_len, Length: 742, dtype: int64

# %%
#competitor count
df['competitor_count'] = df['Competitors'].apply(lambda x: len(x.split(',')) if x != -1 else 0)

# %%
df['competitor_count']
# Out:
# 0      1
# 1      1
# 2      1
# 3      3
# 4      3
#       ..
# 737    3
# 738    3
# 739    1
# 740    1
# 741    1
# Name: competitor_count, Length: 742, dtype: int64

# %%
#hourly wage to annual
df['min_salary']  = df.apply(lambda x: x.min_salary*2  if x.hourly ==1 else x.min_salary, axis=1)
df['max_salary'] = df.apply(lambda x: x.max_salary*2 if x.hourly == 1 else x.max_salary, axis=1)

# %%
df[df.hourly == 1][['hourly','min_salary', 'max_salary']]
# Out:
#      hourly  min_salary  max_salary
# 165       1          34          48
# 177       1          42          68
# 197       1          36          50
# 202       1          42          68
# 210       1          30          50
# 246       1          34          48
# 271       1          42          68
# 337       1          36          50
# 345       1          48          78
# 357       1          42          68
# 363       1          50          56
# 408       1          42          58
# 409       1          20          34
# 492       1          36          50
# 509       1          48          78
# 533       1          42          68
# 542       1          50          56
# 617       1          42          58
# 618       1          20          34
# 645       1          54          94
# 666       1          36          50
# 682       1          48          78
# 711       1          42          68
# 724       1          50          56

# %%
df['company_txt'] = df.company_txt.apply(lambda x: x.replace('\n' , '') if '\n' in x else x)

# %%
df['company_txt']
# Out:
# 0                          Tecolote Research
# 1      University of Maryland Medical System
# 2                                    KnowBe4
# 3                                       PNNL
# 4                         Affinity Solutions
#                        ...
# 737                                      GSK
# 738                               Eventbrite
# 739           Software Engineering Institute
# 740                             Numeric, LLC
# 741             Riverside Research Institute
# Name: company_txt, Length: 742, dtype: object

# %%
df.describe()
# Out:
#            Rating      Founded      hourly  Employer_Provided  min_salary  \
# count  742.000000   742.000000  742.000000         742.000000  742.000000
# mean     3.618868  1837.154987    0.032345           0.022911   74.719677
# std      0.801210   497.183763    0.177034           0.149721   30.980593
# min     -1.000000    -1.000000    0.000000           0.000000   15.000000
# 25%      3.300000  1939.000000    0.000000           0.000000   52.000000
# 50%      3.700000  1988.000000    0.000000           0.000000   69.500000
# 75%      4.000000  2007.000000    0.000000           0.000000   91.000000
# max      5.000000  2019.000000    1.000000           1.000000  202.000000
#
#        max_salary  avg_salary  same state         age   python_yn    excel_yn  \
# count  742.000000  742.000000  742.000000  742.000000  742.000000  742.000000
# mean   128.149596  100.626011    0.557951   49.389488    0.528302    0.522911
# ...

# %%
df.Rating.hist()
# Out:
# <AxesSubplot: >

# %%
df.avg_salary.hist()
# Out:
# <AxesSubplot: >

# %%
df.desc_len.hist()
# Out:
# <AxesSubplot: >

# %%
df.boxplot(column=['age', 'avg_salary', 'Rating'])
# Out:
# <AxesSubplot: >

# %%
df.boxplot(column='Rating')
# Out:
# <AxesSubplot: >

# %%
df[['age', 'avg_salary', 'Rating' , 'desc_len']].corr()
# Out:
#                  age  avg_salary    Rating  desc_len
# age         1.000000    0.019410  0.026164  0.164730
# avg_salary  0.019410    1.000000  0.013492  0.078808
# Rating      0.026164    0.013492  1.000000 -0.012281
# desc_len    0.164730    0.078808 -0.012281  1.000000

# %%
cmap = sns.diverging_palette(220 , 10  , as_cmap=True)
sns.heatmap(df[['age', 'avg_salary', 'Rating' , 'desc_len', 'competitor_count']].corr() , cmap = cmap, square=True , cbar_kws={'shrink': .5}, vmax=.5)
# Out:
# <AxesSubplot: >

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'Employer_Provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'same state', 'age', 'python_yn',
#        'excel_yn', 'r_studio_yn', 'power_bi_yn', 'tabula_yn', 'matplotlib_yn',
#        'math', 'machine learning', 'communication skills', 'job_simp',
#        'seniority', 'desc_len', 'competitor_count'],
#       dtype='object')

# %%
df_categories = df[['Location', 'Headquarters', 'Size', 'Type of ownership', 'Industry', 'Sector', 'Revenue', 'company_txt','job_state', 'same state','python_yn', 'excel_yn', 'r_studio_yn', 'power_bi_yn', 'tabula_yn', 'matplotlib_yn', 'math', 'machine learning', 'communication skills', 'job_simp', 'seniority',]]

# %%
for i in df_categories.columns:
    cat_num = df_categories[i].value_counts()
    print("Graph for %s: total = %d" % (i  , len(cat_num)))
    chart = sns.barplot(x= cat_num.index , y= cat_num)
    chart.set_xticklabels(chart.get_xticklabels() , rotation = 90)
    plt.show()
# Out:
# Graph for Location: total = 200
# Graph for Headquarters: total = 198
# Graph for Size: total = 9
# Graph for Type of ownership: total = 11
# Graph for Industry: total = 60
# Graph for Sector: total = 25
# Graph for Revenue: total = 14
# Graph for company_txt: total = 343
# Graph for job_state: total = 38
# Graph for same state: total = 2
# Graph for python_yn: total = 2
# Graph for excel_yn: total = 2
# Graph for r_studio_yn: total = 1
# Graph for power_bi_yn: total = 2
# Graph for tabula_yn: total = 2
# Graph for matplotlib_yn: total = 2
# Graph for math: total = 1
# Graph for machine learning: total = 2
# Graph for communication skills: total = 2
# Graph for job_simp: total = 7
# Graph for seniority: total = 3

# %%
for i in df_categories[['Location', 'Headquarters' ,'company_txt']].columns:
    cat_num = df_categories[i].value_counts()[:20]
    print("Graph for %s: total = %d" % (i  , len(cat_num)))
    chart = sns.barplot(x= cat_num.index , y= cat_num)
    chart.set_xticklabels(chart.get_xticklabels() , rotation = 90)
    plt.show()
# Out:
# Graph for Location: total = 20
# Graph for Headquarters: total = 20
# Graph for company_txt: total = 20

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'Employer_Provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'same state', 'age', 'python_yn',
#        'excel_yn', 'r_studio_yn', 'power_bi_yn', 'tabula_yn', 'matplotlib_yn',
#        'math', 'machine learning', 'communication skills', 'job_simp',
#        'seniority', 'desc_len', 'competitor_count'],
#       dtype='object')

# %%
pd.pivot_table(df , index = 'job_simp' , values='avg_salary')
# Out:
#                 avg_salary
# job_simp
# analyst          65.857843
# data engineer   105.403361
# data scientist  117.564516
# director        168.607143
# manager          84.022727
# mle             126.431818
# na               84.853261

# %%
pd.pivot_table(df , index =['job_simp', 'seniority'] , values='avg_salary')
# Out:
#                           avg_salary
# job_simp       seniority
# analyst        jr          56.500000
#                na          61.155405
#                senior      79.092593
# data engineer  na          96.701220
#                senior     124.689189
# data scientist jr         106.500000
#                na         107.043011
#                senior     138.956522
# director       na         168.607143
# manager        na          84.022727
# mle            na         119.133333
#                senior     142.071429
# na             na          73.988189
#                senior     109.061404

# %%
pd.set_option('display.max_rows' , None)

# %%
df.pivot_table( index = ['job_state' , 'job_simp'] , values = 'avg_salary' , aggfunc='count').sort_values('job_state'  , ascending=False)
# Out:
#                              avg_salary
# job_state    job_simp
#  WI          na                       4
#              data scientist           3
#              analyst                  3
#  WA          na                       1
#              data scientist          17
#              analyst                  3
#  VA          na                       5
#              mle                      2
#              data scientist          18
#              data engineer           10
#              analyst                  6
#  UT          data engineer            3
#              analyst                  4
#              data scientist           3
#  TX          na                       7
#              data scientist          13
#              data engineer            8
#  TN          data scientist           1
#              data engineer           10
#              analyst                  2
#  SC          na                       1
#  RI          analyst                  1
# ...

# %%
df.pivot_table( index = df[df.job_simp == 'data scientist']['job_state'], values='avg_salary').sort_values('avg_salary' , ascending=False)
# Out:
#               avg_salary
# job_state
#  DC           149.000000
#  CA           143.044776
#  UT           140.500000
#  MO           127.666667
#  IL           117.233333
#  NC           117.000000
#  NY           115.250000
#  MA           113.750000
#  WI           113.500000
#  PA           113.333333
#  MD           109.115385
#  CO           108.666667
#  VA           108.416667
#  Los Angeles  107.500000
#  NJ           106.875000
#  MI           106.625000
#  OH           105.285714
#  TX           100.730769
#  WA            99.764706
#  OR            98.500000
#  FL            97.357143
#  TN            96.000000
#  IN            84.500000
#  KY            84.000000
#  CT            84.000000
#  GA            81.333333
#  NM            74.333333
#  AZ            69.500000

# %%
df_pivots = df[[ 'Rating' , 'Industry' , 'Sector' , 'Revenue' ,'competitor_count'  ,'hourly', 'Employer_Provided' , 'python_yn' , 'excel_yn', 'r_studio_yn', 'power_bi_yn', 'tabula_yn', 'matplotlib_yn', 'math', 'machine learning', 'communication skills','Type of ownership','avg_salary']]

# %%
for i in df_pivots.columns:
    print(i)
    print(pd.pivot_table(df_pivots , index  = i , values = 'avg_salary').sort_values('avg_salary' , ascending=False))
# Out:
# Rating
#         avg_salary
# Rating
# -1.0    136.181818
#  5.0    134.700000
#  2.5    120.000000
#  4.5    117.714286
#  4.1    116.368421
#  3.9    113.071429
#  2.6    109.083333
#  4.4    108.606061
#  3.2    105.500000
#  4.0    105.340426
#  3.5    104.897959
#  3.7    104.131148
#  4.7    103.983871
#  4.3    102.468750
#  3.3    101.858974
#  4.2    100.442308
#  2.2     97.750000
#  4.6     97.250000
#  3.8     96.811475
#  2.1     95.900000
#  3.4     93.011364
#  1.9     87.500000
#  3.1     86.580000
#  3.0     85.588235
#  3.6     85.467391
#  2.8     83.928571
#  2.7     83.250000
#  2.3     81.500000
#  2.9     81.138889
#  4.8     80.277778
#  2.4     60.214286
# Industry
#                                           avg_salary
# Industry
# Other Retail Stores                       163.500000
# Motion Picture Production & Distribution  146.000000
# Financial Analytics & Research            145.125000
# Health, Beauty, & Fitness                 139.500000
# ...

# %%
pd.pivot_table(df_pivots , index = 'Revenue' , columns='python_yn' , values='avg_salary' , aggfunc='count')
# Out:
# python_yn                            0      1
# Revenue
# $1 to $2 billion (USD)            16.0   44.0
# $1 to $5 million (USD)             1.0    7.0
# $10 to $25 million (USD)          16.0   16.0
# $10+ billion (USD)                66.0   58.0
# $100 to $500 million (USD)        47.0   44.0
# $2 to $5 billion (USD)            17.0   22.0
# $25 to $50 million (USD)          24.0   16.0
# $5 to $10 billion (USD)            9.0   10.0
# $5 to $10 million (USD)            9.0    9.0
# $50 to $100 million (USD)         21.0   25.0
# $500 million to $1 billion (USD)  29.0   28.0
# -1                                 1.0    NaN
# Less than $1 million (USD)         1.0    3.0
# Unknown / Non-Applicable          93.0  110.0

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
import nltk
nltk.download('punkt');
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\khatib\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
words = "".join(df['Job Description'])
def punctuation_stop(text):
    filterd =  []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not  in stop_words and w.isalpha():
            filterd.append(w.lower())

    return filterd

# %%
words_filtered  = punctuation_stop(words)

text = ''.join([ele for ele in words_filtered])
wc = WordCloud(background_color='white' , random_state=1 , stopwords=STOPWORDS , max_words=2000 , width=800 , height=1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[99], line 5
#       3 text = ''.join([ele for ele in words_filtered])
#       4 wc = WordCloud(background_color='white' , random_state=1 , stopwords=STOPWORDS , max_words=2000 , width=800 , height=1500)
# ----> 5 wc.generate(text)
#       7 plt.figure(figsize=[10,10])
#       8 plt.imshow(wc,interpolation='bilinear')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:639, in WordCloud.generate(self, text)
#     624 def generate(self, text):
#     625     """Generate wordcloud from text.
#     626
#     627     The input "text" is expected to be a natural text. If you pass a sorted
#    (...)
#     637     self
#     638     """
# --> 639     return self.generate_from_text(text)
#
# ...
